# %%
# data taken from
# http://www.sahistory.org.za/topic/june-16-soweto-youth-uprising
# and cleaned up
table = """
<table class="dataTable full" style="width: 611px; height: 12111px;">
<thead>
<tr>
<th scope="col">Name</th>
<th scope="col">Place of death</th>
<th scope="col">Age</th>Eliakim Sutu
<th scope="col">Date</th>
<th scope="col">Cause of death</th>
</tr>
</thead>
<tbody readability="117">
<tr readability="2">
<td><a id="locA" name="locA"></a>Adams, Sandra Joyce</td>
<td>Kew Town</td>
<td>15</td>
<td>16.9.76</td>
<td>Shot in front of head (ricochet) on 3rd floor balcony</td>
</tr>
<tr readability="2">
<td>Adriaanse, Noel John</td>
<td>Hanover Park</td>
<td>13</td>
<td>2.9.76</td>
<td>Shot through left side of head</td>
</tr>
<tr readability="2">
<td>Africa, Pieter</td>
<td>Montagu</td>
<td>24</td>
<td>11.9.76</td>
<td>White Supply. Details of death under investigation</td>
</tr>
<tr>
<td>Albern, Bazil</td>
<td>Elsies River</td>
<td>16</td>
<td>9.9.76</td>
<td>Shot to side of abdomen</td>
</tr>
<tr>
<td>Allie, Abduraghman</td>
<td>Ravensmead</td>
<td>&nbsp;</td>
<td>7.9.76</td>
<td>Shot in chest from front</td>
</tr>
<tr readability="3">
<td>Appolis, Christopher</td>
<td>Manenberg</td>
<td>16</td>
<td>10.9.76</td>
<td>Shot in head from front, Jordaan Road</td>
</tr>
<tr readability="2">
<td>August, Victor L.</td>
<td>Gugulethu</td>
<td>&nbsp;</td>
<td>31.12.76</td>
<td>Reported missing during December disturbances</td>
</tr>
<tr readability="2">
<td><a id="locB" name="locB"></a>Bakubaku, Golden</td>
<td>Nyanga</td>
<td>&nbsp;</td>
<td>26.12.76</td>
<td>Killed by migrant workers</td>
</tr>
<tr readability="3">
<td>Balnardo, Gary Sandy</td>
<td>Grassy Park</td>
<td>19</td>
<td>16.9.76</td>
<td>Shot through buttock and chest from front, at Head Road.</td>
</tr>
<tr>
<td>Barnes, Isaac</td>
<td>Bonteheuwel</td>
<td>16</td>
<td>25.8.76</td>
<td>Shot in chest from front</td>
</tr>
<tr readability="2">
<td>Barnes, Sydney</td>
<td>Gugulethu</td>
<td>32</td>
<td>26.8.76</td>
<td>Beaten to death by group of migrant workers</td>
</tr>
<tr>
<td>Barron, James</td>
<td>Soweto</td>
<td>&nbsp;</td>
<td>26.12.76</td>
<td>Shot through the head</td>
</tr>
<tr>
<td>Bezuidenhout, Isaac</td>
<td>Mosselbay</td>
<td>&nbsp;</td>
<td>14.9.76</td>
<td>Burried</td>
</tr>
<tr>
<td>Bota, Michael</td>
<td>Nyanga</td>
<td>&nbsp;</td>
<td>26.12.76</td>
<td>Shot dead</td>
</tr>
<tr readability="2">
<td>Botha, William</td>
<td>Nyanga</td>
<td>&nbsp;</td>
<td>26.12.76</td>
<td>Killed by migrant workers</td>
</tr>
<tr readability="2">
<td>Botha, Neville, J.G.</td>
<td>Retreat</td>
<td>20</td>
<td>8.9.76</td>
<td>Shot in stomach from front</td>
</tr>
<tr>
<td>Buba, Lawrence</td>
<td>Philippi</td>
<td>14</td>
<td>9.9.76</td>
<td>Shot in chest from front</td>
</tr>
<tr readability="2">
<td>Buthelezi, Leonard</td>
<td>Soweto</td>
<td>39</td>
<td>4.8.76</td>
<td>Gunshot wounds to the head and body</td>
</tr>
<tr readability="2">
<td>Buthelezi, Joyce</td>
<td>&nbsp;</td>
<td>16</td>
<td>26.12.76</td>
<td>Shotgun wounds to chest and head when police fired on students at Sekano-Ntoane High School</td>
</tr>
<tr>
<td>Carolissen, Gasant</td>
<td>Hanover Park</td>
<td>21</td>
<td>2.9.76</td>
<td>Shot in chest from front</td>
</tr>
<tr>
<
Xhiphu, Mncedisi^ Gugulethu 28 6.9.76 Shot;
Yasin, Ridwaan^ Cape Town 23 7.9.76 Shot. Wounds received in Darling Street;
Zantsi, Sonnyboy^ Gugulethu 17 16.9.76 Shot in front of head;
Zondani, Vuyisile W.^ Manenberg 28 9.9.76 Shot through chest from;
Zuba, Godfrey P^ Gugulethu 23 13.8.76 Shot in stomach from front
"""

# %%
import re

known_names = set()
place_age_date_detail_re = re.compile('(?P<place>[^0-9]*) (?P<age>\d.*) (?P<date>\d*\.\d*\.\d*) ?(?P<detail>.*)')
colin_arendse_lines = [ line for line in colin_arendse_data.split('\n') if line != '' ]
colin_arendse_matrix = {}
for line in colin_arendse_lines:
    line = line.strip()
    [name, rest] = line.split('^')
#     name_parts = name.split(',')
#     name = name_parts[1] + ' ' + name_parts[0]
    rest = rest.strip()
    rest = rest.rstrip(';')
    match = place_age_date_detail_re.match(rest)
    if match is None:
        print("PROBLEM:", rest)
    place_str = match.group('place')
    age_str = None if match.group('age') == '99' else match.group('age')
    date_str = None if match.group('date') == '99.99.99' else match.group('date')
    try:
        detail_str = match.group('detail')
    except IndexError:
        detail_str = None
    row = {'Age': age_str, 'Date': date_str, 'Place of death': place_str, 'Cause of death': detail_str }
    colin_arendse_matrix[name] = row

# %%
import pandas as pd
import geopandas as gpd

# %%
data = pd.read_html(table, index_col="Name")[0]
data.columns
# Out:
# Index(['Place of death', 'Age', 'Date', 'Cause of death'], dtype='object')

# %%
colin_arendse_df = pd.DataFrame.from_dict(colin_arendse_matrix, orient='index')
colin_arendse_df
data = pd.concat([data, colin_arendse_df])
data
# Out:
# /home/pvh/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   app.launch_new_instance()
#                           Age  \
# Adams, Sandra Joyce        15
# Adriaanse, Noel John       13
# Africa, Pieter             24
# Albern, Bazil              16
# Allie, Abduraghman        NaN
# Appolis, Christopher       16
# August, Victor L.         NaN
# Bakubaku, Golden          NaN
# Balnardo, Gary Sandy       19
# Barnes, Isaac              16
# Barnes, Sydney             32
# Barron, James             NaN
# Bezuidenhout, Isaac       NaN
# Bota, Michael             NaN
# Botha, William            NaN
# Botha, Neville, J.G.       20
# Buba, Lawrence             14
# Buthelezi, Leonard         39
# ...

# %%
from geopy.geocoders import Nominatim
from geopy.geocoders import GoogleV3
from geopy.exc import GeocoderTimedOut
nom = Nominatim()
google = GoogleV3()

# %%
from threading import Thread, Lock, Condition
from functools import partial

# %%
def lookup(coder, timeout, work, work_condition, lock, loc_dict, sig):
    name = None
    while name != 'SHUTDOWN':
        with work_condition:
            print(sig, end='')
            if len(work) > 0:
                name = work.pop()
            else:
                name = 'SHUTDOWN'
        if name not in loc_dict:
            timeout = False
            try:
                location = coder.geocode(name, timeout=timeout)
            except GeocoderTimedOut:
                location = None
                timeout = True
            if location is not None:
                lock.acquire()
                loc_dict[name] = location
                lock.release()
            elif not timeout and location is None:
                lock.acquire()
                loc_dict[name] = 'UNKNOWN'
                lock.release()

work_cond = Condition()
lookup_lock = Lock()
work = []
place_dict = dict()

for place in data["Place of death"]:
    if not pd.isnull(place):
        place_str = place + ', South Africa'
        work.append(place_str)

threads = []
for sig in ('.','*','-','^'):
    thread = Thread(target=lookup, args=(nom, 10, work, work_cond, lookup_lock, place_dict, sig))
    threads.append(thread)
    thread.start()

thread_count = len(threads)
for thread in threads:
    thread.join()

print('Done')
# Out:
# .*-^---*.^---.^*-^^^...*-^**.........-------^^^^*******************^.^.^^^.^........------------*************^^^^*******.*.....-^^*.-^***************.....................------------------------------------^^^^^^^^^^^*****...********........--------------------------------------------------------------------------------------------------------------------^^^^^^^^^^^^^^^^^^^^^^^^^^^^^**********....................--^^^^^^^^^^^^^^^^^^^^^^^*......-------------------------^*.-Done

# %%
for place in data["Place of death"]:
    if not pd.isnull(place):
        place_str = place + ', South Africa'

# %%
place_dict.keys()
# Out:
# dict_keys(['Montagu, South Africa', 'Moepong, South Africa', 'Mabopane, South Africa', 'Manenberg, South Africa', 'Cape Town, South Africa', 'Kew Town, South Africa', 'Retreat, South Africa', 'Elsies River, South Africa', 'Cloetesville, South Africa', 'Gugulethu, South Africa', 'Kagiso, South Africa', 'Alexandra, South Africa', 'Heideveld, South Africa', 'Hanover Park, South Africa', 'Langa, South Africa', 'Huguenot, Paarl, South Africa', 'Lansdown, South Africa', 'Pretoria, Mamelodi, South Africa', 'Kuilsrivier, South Africa', 'Athlone, South Africa', 'Dobsonville, South Africa', 'Silvertown, South Africa', 'Nyanga, South Africa', 'Philippi, South Africa', "Elsies' River, South Africa", "Elsis' River, South Africa", 'Soweto, South Africa', 'Grassy Park, South Africa', 'Moletsane, South Africa', 'Camps Bay, South Africa', "Elsie's River, South Africa", 'Bonteheuwel, South Africa', 'Mamelodi, South Africa', 'Mosselbay, South Africa', 'District Six, South Africa', 'Daveyton, South Afri
# ...

# %%
print(len(place_dict))
# Out:
# 42

# %%
print([ name for name in place_dict.keys() if place_dict[name] == 'UNKNOWN'])
# Out:
# ['Moepong, South Africa', 'Lansdown, South Africa', 'Epton, South Africa']

# %%
from shapely.geometry import Point

new_column = []
for index, row in data.iterrows():
    place = row["Place of death"]
    if not pd.isnull(row["Place of death"]):
        place_str = place + ', South Africa'
        if place_str in place_dict and place_dict[place_str] != 'UNKNOWN':
            coordinates = place_dict[place_str][1]
            new_column.append(Point(coordinates[0], coordinates[1]))
        else:
            new_column.append(None)
    else:
        new_column.append(None)
new_column_series = pd.Series(new_column, index=data.index)

# %%
death_data = data.merge(new_column_series.to_frame(name='DeathLocation'), left_index=True, right_index=True)

# %%
import random
import folium
from folium.plugins import MarkerCluster


def place_on_map(data, themap):
    cross_icon = folium.features.CustomIcon('https://pvanheus.github.io/1976/cross_marker.png', 
                                            icon_size=[15, 25], 
                                            icon_anchor=[7, 12], popup_anchor=[0, -6])
    markers_layer = folium.FeatureGroup(name='Deaths')
    unknown_place_str = ''
    names_seen = set()
    places_seen = set()
    icons = []
    locations = []
    popups = []
    for index, row in data.iterrows():
        unknown_place = False
        name = index
        if "," in name:
            parts = name.split(",")
            name = parts[1] + ' ' + parts[0]
            name = name.replace('"', "'")
        if name in names_seen:
            continue
        names_seen.add(name)
        date_str = '' if pd.isnull(row["Date"]) else str(row["Date"]) + '<br />'  
        detail_str = '' if pd.isnull(row["Cause of death"]) else str(row["Cause of death"])    

        if pd.isnull(row["Place of death"]):
            unknown_place = True
        else:
            place_str = row["Place of death"] + ', South Africa'
        if place_str not in place_dict or place_dict[place_str] == 'UNKNOWN':
            unknown_place = True


        if unknown_place:
            unknown_place_str += """
                <tr>
                    <td>{name}</td>
                    <td>{date}</td>
                    <td>{detail}</td>
                </tr>    
            """.format(name=name, date=date_str, detail=detail_str)
            continue

        if place_str in places_seen:
            fudge_lat = (random.random() - 0.5) / 50
            fudge_long = (random.random() - 0.5) / 50
        else:
            fudge_lat = 0
            fudge_long = 0
            places_seen.add(place_str)
        age_str = '' if pd.isnull(row["Age"]) else ', ' + str(row["Age"])
        name_row = '<b>' + name + age_str + '</b><br />'
        short_place = str(row["Place of death"]) + '<br />'
        location = list(place_dict[place_str][1])
        location[0] += fudge_lat
        location[1] += fudge_long
        location_str = str(location)
        popup_string = '<b>{person}</b><br />{date}{place}{detail}'
        locations.append(location)
        popups.append(folium.IFrame(popup_string, width = 300, height = 100))
        icons.append(folium.features.CustomIcon('https://pvanheus.github.io/1976/cross_marker.png', 
                                            icon_size=[15, 25], 
                                            icon_anchor=[7, 12], popup_anchor=[0, -6]))


    cluster = MarkerCluster(locations=locations, popups=popups, icons=icons).add_to(markers_layer)
    markers_layer.add_to(themap)
    return unknown_place_str

# %%
import folium

sa_map = folium.Map(location=[-28.996293, 25.086904], zoom_start=6)

place_on_map(death_data, sa_map)

sa_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
SA_shape = gpd.read_file('southafrica/ZAF_adm0.shp')

# %%
print(SA_shape.centroid.geometry.x, SA_shape.centroid.geometry.y)
# Out:
# 0    25.086904
# dtype: float64 0   -28.996293
# dtype: float64

# %%
header = """
<!DOCTYPE html>
<html>
<head>
	<title>1976</title>

	<meta charset="utf-8" />
    <link rel="icon" type="image/png" href="http://pvanheus.github.io/1976/cross_marker.png" />
    
	<meta name="viewport" content="width=device-width, initial-scale=1.0">

	<link rel="shortcut icon" type="image/x-icon" href="docs/images/favicon.ico" />

    <link rel="stylesheet" href="https://unpkg.com/leaflet@1.0.3/dist/leaflet.css" integrity="sha512-07I2e+7D8p6he1SIM+1twR5TIrhUQn9+I6yjqD53JQjFiMf8EtC93ty0/5vJTZGF8aAocvHYNEDJajGdNx1IsQ==" crossorigin=""/>

    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/materialize/0.98.2/css/materialize.min.css">

<script type="text/javascript" src="https://code.jquery.com/jquery-2.1.1.min.js"></script>
<script src="https://unpkg.com/leaflet@1.0.3/dist/leaflet.js" integrity="sha512-A7vV8IFfih/D732iSSKi20u/ooOfj/AGehOKq0f4vLT1Zr2Y+RX7C+w8A1gaSasGtRUZpF/NZgzSAu4/Gc41Lg==" crossorigin=""></script>
<script src="https://cdnjs.cloudflare.com/ajax/libs/materialize/0.98.2/js/materialize.min.js"></script>
</head>
<body>
<div class="container">
    <div class="row">
        <div class="col s8 offset-s2">

<center>
<h4>In memory of 1976</h4>
<p>June 16 1976 marks the start of the 1976 youth uprising against Apartheid in South Africa. Most closely associated
with the school students march in Soweto and the murder of Hector Pieterson, the revolt spread across the country
and well past June 1976. Along with the revolt came the deaths, most often of those shot by police. The
South African History Online website has tried to collect a 
<a href="http://www.sahistory.org.za/topic/june-16-soweto-youth-uprising">list</a> of the "casaulties of 
1976". I have taken that list, done a little cleanup (code is <a href="https://github.com/pvanheus/1976">here</a>)
and produced the map below.</p>

<center><div id="mapid" style="width: 800px; height: 700px;"></div>
<script>
	var mymap = L.map('mapid').setView([-28.8097176,24.6074293], 6);
    
    var cross_icon = L.icon({
        iconUrl: 'cross_marker.png',
        iconSize: [15, 25],
        iconAnchor: [7, 12],
        popupAnchor: [0, -6]
    });

	L.tileLayer('https://api.tiles.mapbox.com/v4/{id}/{z}/{x}/{y}.png?access_token=pk.eyJ1IjoibWFwYm94IiwiYSI6ImNpejY4NXVycTA2emYycXBndHRqcmZ3N3gifQ.rJcFIG214AriISLbB6B5aw', {
		maxZoom: 18,
		attribution: 'Map data &copy; <a href="http://openstreetmap.org">OpenStreetMap</a> contributors, ' +
			'<a href="http://creativecommons.org/licenses/by-sa/2.0/">CC-BY-SA</a>, ' +
			'Imagery © <a href="http://mapbox.com">Mapbox</a>',
		id: 'mapbox.streets'
	}).addTo(mymap);
    
"""

footer = """
<p>The map will be updated as more complete data becomes available. Locations have been found by looking
up the listed location and converting into a geographical place. Where there is an overlap of place,
a small random factor has been added to avoid markers overlapping.</p>
<p>Page contents licensed according to <a href="LICENSE">GPLv3.0</a>.</p>
</center>
        </div> <!-- col -->
    </div> <!-- row -->
</div> <!-- container -->

</body>
</html>
"""

# %%
import random
names_seen = set()
output = header
places_seen = set()
count = 0
unknown_place_str = """
<p>
    <table class="bordered">
        <caption>Place of death unknown</caption>
        <tr>
            <th>Name</th>
            <th>Date</th>
            <th>Cause of death</th>
        </tr>
"""
deaths_list = []
for index, row in data.iterrows():
    unknown_place = False
    name = index
    if "," in name:
        parts = name.split(",")
        name = parts[1] + ' ' + parts[0]
        name = name.replace('"', "'")
    if name in names_seen:
        continue
    names_seen.add(name)
    count +=1    
    date_str = '' if pd.isnull(row["Date"]) else str(row["Date"]) + '<br />'  
    detail_str = '' if pd.isnull(row["Cause of death"]) else str(row["Cause of death"])    

    if pd.isnull(row["Place of death"]):
        unknown_place = True
    else:
        place_str = row["Place of death"] + ', South Africa'
    if place_str not in place_dict or place_dict[place_str] == 'UNKNOWN':
        unknown_place = True


    if unknown_place:
        unknown_place_str += """
            <tr>
                <td>{name}</td>
                <td>{date}</td>
                <td>{detail}</td>
            </tr>    
        """.format(name=name, date=date_str, detail=detail_str)
        continue
        
    if place_str in places_seen:
        fudge_lat = (random.random() - 0.5) / 50
        fudge_long = (random.random() - 0.5) / 50
    else:
        fudge_lat = 0
        fudge_long = 0
        places_seen.add(place_str)
    age_str = '' if pd.isnull(row["Age"]) else ', ' + str(row["Age"])
    name_row = '<b>' + name + age_str + '</b><br />'
    short_place = str(row["Place of death"]) + '<br />'
    location = list(place_dict[place_str][1])
    location[0] += fudge_lat
    location[1] += fudge_long
    location_str = str(location)
    
    deaths_list.append(dict(place=row["Place of death"], timestamp=date_to_timestamp(date_str),
                            latitude=location[0], longitude=location[1], person=name.strip(), 
                            age=age_str.strip(', '), detail=detail_str))
    output += """
    	L.marker({location}, {{icon: cross_icon}}).addTo(mymap)
		.bindPopup("<b>{person}</b><br />{date}{place}{detail}");
    """.format(location=location_str, person=name_row, date=date_str, place=short_place,
               detail=detail_str)

output += "</script>\n"
output += unknown_place_str + """
    \n</table>\n</p>\n<p>{number} deaths recorded. This is an undercount of those who
    were killed, not all deaths have been captured in this data.</p>
    """.format(number=count)
output += footer
output_file = open('1976_gen.html', 'w')
output_file.write(output)
output_file.close()
print(count)
# Out:
# 427

# %%
from bs4 import BeautifulSoup
import requests

# %%
response = requests.get('https://www.sahistory.org.za/topic/june-16-soweto-youth-uprising-casualties')

# %%
if response.ok:
    page = response.text
soup = BeautifulSoup(page, 'html.parser')

# %%
rows = []
for row_el in soup.find_all('tr'):
    columns = list(row_el.find_all('td'))
    if len(columns) == 5:
        name = columns[0].string
        if len(columns[0]) == 2:
            name = columns[0].contents[1].string
        place_of_death = columns[1].string
        age = columns[2].string
        date = columns[3].string
        cause_of_death = columns[4].string
        row_dict = {'name': name, 'place_of_death': place_of_death,
                    'age': age, 'date': date, 'cause_of_death': cause_of_death}
        rows.append(row_dict)
new_data = pd.DataFrame(rows)

# %%
new_data[new_data.place_of_death == 'Retreat']
# Out:
#     age                           cause_of_death     date  \
# 15   20               Shot in stomach from front   8.9.76
# 25   37                  Shot in lungs and heart   8.9.76
# 27   35               Shot in left side of chest   8.9.76
# 44   15   Shot in right side of chest from front   9.9.76
# 68   31                 Shot in neck from behind   9.9.76
# 123  34                  Shot in neck from front   8.9.76
# 207  18                    Shot in small of back  16.9.76
# 227  18  Shot in back, neck and head from behind   8.9.76
# 238  19                             Shot in back   8.9.76
# 425  20                 Shot in chest from front  13.9.76
# 514  22                  Shot left side of chest   8.9.76
# 517  23                         Shot in the back   8.9.76
# 523  15        Shot in left shoulder from behind   9.9.76
#
#                       name place_of_death
# 15    Botha, Neville, J.G.        Retreat
# 25         Dajee, Bhanudey        Retreat
# ...

# %%
def date_to_timestamp(date: str):
    """return a datetime from a date (cleaning it up along the way)"""
    date = date.replace('\x0a', '').strip()  # remove remains of &nbsp;
    date = date.replace('.756', '.76')
    if date == '':
        date = '16.6.76'  # default to 16 June 1976
    elif '1276' in date:
        date = date[0] + date[1] + '.12.76'
    else:
        date_re = re.compile('(?P<day>\d+)\D(?P<month>\d+)\D(?P<year>\d+)')
        match = date_re.match(date)
        assert match is not None, "Failed to match on {} {}".format(date, len(date))
        date = '.'.join([match.group('day'), match.group('month'), match.group('year')])
    now = datetime.datetime.now()
    return now.strptime(date, '%d.%m.%y').timestamp()

# %%
date_to_timestamp('31.12.76')
# Out:
# 220831200.0

# %%
deaths_list
# Out:
# [{'age': '15',
#   'detail': 'Shot in front of head (ricochet) on 3rd floor balcony',
#   'latitude': -33.9367988,
#   'longitude': 18.4023586,
#   'person': 'Sandra Joyce Adams',
#   'place': 'Kew Town',
#   'timestamp': 211672800.0},
#  {'age': '13',
#   'detail': 'Shot through left side of head',
#   'latitude': -33.9922222,
#   'longitude': 18.5330556,
#   'person': 'Noel John Adriaanse',
#   'place': 'Hanover Park',
#   'timestamp': 210463200.0},
#  {'age': '24',
#   'detail': 'White Supply. Details of death under investigation',
#   'latitude': -33.782221,
#   'longitude': 20.121103,
#   'person': 'Pieter Africa',
#   'place': 'Montagu',
#   'timestamp': 211240800.0},
#  {'age': '16',
#   'detail': 'Shot to side of abdomen',
#   'latitude': -33.9105182,
#   'longitude': 18.5691093,
#   'person': 'Bazil Albern',
#   'place': 'Elsies River',
#   'timestamp': 211068000.0},
#  {'age': '',
#   'detail': 'Shot in chest from front',
#   'latitude': -33.9211111,
# ...

# %%
import json

# %%
json.dump(deaths_list, open('1976_deaths.json', 'w'))

# %%
data
# Out:
#                           Age  \
# Adams, Sandra Joyce        15
# Adriaanse, Noel John       13
# Africa, Pieter             24
# Albern, Bazil              16
# Allie, Abduraghman        NaN
# Appolis, Christopher       16
# August, Victor L.         NaN
# Bakubaku, Golden          NaN
# Balnardo, Gary Sandy       19
# Barnes, Isaac              16
# Barnes, Sydney             32
# Barron, James             NaN
# Bezuidenhout, Isaac       NaN
# Bota, Michael             NaN
# Botha, William            NaN
# Botha, Neville, J.G.       20
# Buba, Lawrence             14
# Buthelezi, Leonard         39
# Buthelezi, Joyce           16
# Carolissen, Gasant         21
# Carolissen, Ronald C.      22
# Cezala, Bonekeli          NaN
# Cloete, Joseph E.          30
# Cook, Faried               16
# Cooke, Rodney              24
# Dajee, Bhanudey            37
# Daniels, Patrick J         24
# Daniels, John              35
# Daniels, Kammips           33
# Davids, John               16
# ...

# %%
len(pd.Series(data=latitudes, name='latitudes'))
# Out:
# 383

# %%
data
# Out:
#                           Age  \
# Adams, Sandra Joyce        15
# Adriaanse, Noel John       13
# Africa, Pieter             24
# Albern, Bazil              16
# Allie, Abduraghman        NaN
# Appolis, Christopher       16
# August, Victor L.         NaN
# Bakubaku, Golden          NaN
# Balnardo, Gary Sandy       19
# Barnes, Isaac              16
# Barnes, Sydney             32
# Barron, James             NaN
# Bezuidenhout, Isaac       NaN
# Bota, Michael             NaN
# Botha, William            NaN
# Botha, Neville, J.G.       20
# Buba, Lawrence             14
# Buthelezi, Leonard         39
# Buthelezi, Joyce           16
# Carolissen, Gasant         21
# Carolissen, Ronald C.      22
# Cezala, Bonekeli          NaN
# Cloete, Joseph E.          30
# Cook, Faried               16
# Cooke, Rodney              24
# Dajee, Bhanudey            37
# Daniels, Patrick J         24
# Daniels, John              35
# Daniels, Kammips           33
# Davids, John               16
# ...

# %%
data
# Out:
#                           Age  \
# Adams, Sandra Joyce        15
# Adriaanse, Noel John       13
# Africa, Pieter             24
# Albern, Bazil              16
# Allie, Abduraghman        NaN
# Appolis, Christopher       16
# August, Victor L.         NaN
# Bakubaku, Golden          NaN
# Balnardo, Gary Sandy       19
# Barnes, Isaac              16
# Barnes, Sydney             32
# Barron, James             NaN
# Bezuidenhout, Isaac       NaN
# Bota, Michael             NaN
# Botha, William            NaN
# Botha, Neville, J.G.       20
# Buba, Lawrence             14
# Buthelezi, Leonard         39
# Buthelezi, Joyce           16
# Carolissen, Gasant         21
# Carolissen, Ronald C.      22
# Cezala, Bonekeli          NaN
# Cloete, Joseph E.          30
# Cook, Faried               16
# Cooke, Rodney              24
# Dajee, Bhanudey            37
# Daniels, Patrick J         24
# Daniels, John              35
# Daniels, Kammips           33
# Davids, John               16
# ...
